# %%
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq
import torch
import os
import re
import librosa
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn.functional as F
import pandas as pd

# Load experiment data with stimuli
xls = pd.ExcelFile('data/experiment_data.xlsx')
experiment_data = {}
# Iterate through sheet names and load into the dictionary
for sheet_name in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet_name)
    sheet_name = sheet_name.lower().rstrip('-ru')
    experiment_data[sheet_name] = df

# %%
processor = AutoProcessor.from_pretrained("mitchelldehaven/whisper-medium-ru")
model = AutoModelForSpeechSeq2Seq.from_pretrained("mitchelldehaven/whisper-medium-ru")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/830 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# Downloading normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading config.json:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/3.06G [00:00<?, ?B/s]

# %%
# Preprocess the audio data
inputs = processor(audio_data['BE']['1'][-2], return_tensors="pt", sampling_rate=16000).input_features

# Create dummy decoder_input_ids
decoder_input_ids = torch.tensor([[1, 1]]) * model.config.decoder_start_token_id

# Generate logits from the model
with torch.no_grad():
    logits = model(inputs, decoder_input_ids=decoder_input_ids).logits

# Print the shape of the last hidden state
print(list(logits.shape))
# Out:
# [1, 2, 51865]

# %%
def load_audio_files(language):
    """
    Load the audio data in appropriate format for LMs
    """
    audio_directory = f"data/audio_data/full_audio"
    
    if not os.path.exists(audio_directory):
        print(f"Error: Directory '{audio_directory}' not found.")
        return None

    audio_files = [f for f in os.listdir(audio_directory) if f.endswith(".wav")]
    
    all_data = {}
    
    for index, row in experiment_data[language.lower()].iterrows():
        row_number_str = str(index + 1)
        sentence_l2 = row['sentence l2']
        phrase_ru = row['phrase ru']
        phrase_l2 = row['phrase l2']
        audio_file_path = next((os.path.join(audio_directory, f) for f in audio_files if re.search(rf'{language}_{row_number_str}\.wav', f)), None)

        if audio_file_path:
            # Load audio data using librosa
            audio_data, sr = librosa.load(audio_file_path, sr=16000)
            # Calculate duration in seconds
            duration = len(audio_data) / sr
            all_data[row_number_str] = (phrase_ru, phrase_l2, sentence_l2, audio_data, duration)
        else:
            print(f"Warning: Audio file not found for row {row_number_str}, {language}")

    return all_data

# Example usage for loading audio for different languages
languages = ["BE", "BG", "CS", "UK", "PL"]
audio_data = dict()
for language in languages:
    audio_data[language] = load_audio_files(language)

audio_data['BE']['1']
# Out:
# ('не раз',
#  'не раз',
#  'не раз відаць яны пра гэта гаварылі…',
#  array([-0.00072414, -0.00259487, -0.00278208, ...,  0.000322  ,
#          0.00276465,  0.        ], dtype=float32),
#  3.2298125)

# %%
audio_duration = dict()
for language in languages:
    audio_duration[language] = dict()
    # Iterate through each row in the DataFrame
    for index, row in experiment_data[language.lower()].iterrows():
        sentence_l2 = row['sentence l2']
        audio_file_times = row['audio_file_times'].split(',')
    
        if len(audio_file_times) == 4:
            # If audio_file_times has 3 parts, set start as the first number, and end as the sum of the first two numbers
            start = float(audio_file_times[0])
            end = start + float(audio_file_times[1])
        elif len(audio_file_times) == 3:
            # If audio_file_times has 2 parts
            phrase_l2 = row['phrase l2']
    
            # Check if phrase_l2 is at the beginning of sentence_l2
            if sentence_l2.strip('i ').strip('— ').startswith(phrase_l2):

                start = None
                end = float(audio_file_times[0])
            elif sentence_l2.strip('?').strip('.').endswith(phrase_l2):
                start = float(audio_file_times[0])
                end = None
            else:
                print(phrase_l2, sentence_l2, audio_file_times)
                # Handle other cases as needed
                start = None
                end = None
        else:
            # Handle other cases as needed
            print(phrase_l2, sentence_l2, audio_file_times)
            start = None
            end = None
    
        # Store the result in the dictionary
        audio_duration[language][sentence_l2] = (start, end)
audio_duration
# Out:
# {'BE': {'не раз відаць яны пра гэта гаварылі…': (None, 1.09),
#   'і колькі б я не зарабляў, хоць мільён, хоць сто мільёнаў, табе ўсе роўна будзе мала.': (4.589,
#    5.1000000000000005),
#   'старшыня беларускага фонду культуры уладзімір гілеп прэзентаваў у ялце новае арыгінальнае выданне твораў максіма багдановіча, толькі што выпушчанае ў свет фондам культуры.': (8.357,
#    8.963),
#   '— у свярдлоўску сыйшла, — сказаў я першае, што прыйшло ў галаву, і тут жа падумаў: “а, можа, і праўда: у свярдлоўску сыйшла?..': (4.966,
#    5.2620000000000005),
#   'да гэтай пары яны мне любоўна кажуць: “якое гладкае ў цябе і мускулістае цела…”': (None,
#    1.682),
#   'ступак нешта мармытаў у адказ, што мала разумее сам.': (1.584, 2.167),
#   'капітан між тым варухнуў упартым падбародкам, паказваючы кудысьці ўбок.': (4.348,
#    None),
#   'такім чынам, шматлікія версіі сышліся ў непрыемнай знаходцы шэрагу містыфікацый, якія больш за паўстагоддзя нацягвалі на сябе маску арыгінальных тэкстаў.': (7.682,
#    8.14),
#   'зрэшты, асабліва нікога і не шукалі, адразу населі на гэтых чатырох пуцейцаў,  хоць,  па сутнасці,  ніякіх канкрэтных супраць іх улік і не мелі.': (6.529,
#    7.1259999999999994),
#   'хаця, ты ведаеш, мне часам здаецца, што я ўсе жыцце быў мужыком.': (3.695,
#    4.237),
#   'сікхізм уяўляе сабой рэлігію што паходзіць з індыйскага субкантынента. яна зявілася ў 15 стагоддзі ў рэгіене пенджаб у выніку ўзнікнення ў індуізме розных сектанцкіх груп.': (9.141,
#    9.669),
#   'ведаеш, наташанька, я самая шчаслівая жанчына на свеце, калі ў мяне есць такі муж.': (3.265,
#    3.862),
#   'хіба толькі хітрыць будзе, паказваючы, нібы яму тужліва': (None, 1.111),
#   "шмат млекакормячых з'явілася на галапагосах з моманту прыбыцця туды чалавека, у тым ліку коз, коней, кароў, катоў, сабак і пацукоў.": (5.376,
#    6.446000000000001),
#   'можаце быць упэўнены, што, як толькі вы трапіце на прыстань ці прычал, усе стане відавочна.': (2.355,
#    2.848),
#   'яна не верыць мне і думае, што яе пакараюць не так, як мяне, а то і апраўдаюць: яна ж баранілася.': (4.075,
#    4.6160000000000005),
#   'згодна з паведамленнем ўладаў штата агая, супраць лекара дзіцячай бальніцы горада пітсбурга, штат пенсільванія, будуць выстаўлены абвінавачванні ў забойстве пры абцяжваючых абставінах, пасля таго, як у сераду яе маці знайшлі мертвай у яе машыне.': (10.718,
#    11.599),
#   'ды й думаў я не так, як крабіч, а наадварот: чым больш нармальных людзей ва ўладзе, тым лепш — яны павінны там быць.': (2.777,
#    3.6420000000000003),
#   'тыгр здольны лазіць (але не так добра).': (1.839, 2.182),
#    11.988),
#   'татко цял живот само с фьодор михайлович се е занимавал.': (0.815, 1.476),
#   'парагвай, преди наричан „гигантската провинция на индия“, е роден през 16-ти век в резултат на срещата на испанските завоеватели с местните групи.': (5.776,
#    6.445),
#   'няма вече такива девойки на света, помисли си той.': (2.013, 2.675),
#   'освен да… – взе синята папка от масата. дръжте.': (None, 1.489),
#   'задържани са от вас наши кораби, в това число и „малака“, наета за рейс до япония.': (3.078,
#    3.9379999999999997),
#   'това стана ясно още щом минахме през портала.': (2.054, 2.683),
#   'салов съобщи на панафидин, че в района на шикотан мъглата се задържа понякога месец, че даже и повече…': (6.751,
#    7.586),
#   'след като информацията, оповестена от журналиста макис триантафилопулос в популярното му телевизионно предаване „zoungla“ по алфа тв, депутатът и адвокат, петрос мантувалос, се отказа от поста си.': (None,
#    1.426),
#   'колкото повече мислех по този въпрос, толкова повече се убеждавах, че познавам младежа.': (None,
#    1.573),
#   'тигърът, като добре закръглен атлет, може да се катери (макар и не добре), да плува, да прави огромни скокове и да дърпа със силата на петима здрави човека.': (3.77,
#    4.277),
#   'да не би да ми стане по-леко от това, че е машина.': (2.976, 3.599),
#   'та нали те нямаха нищо, освен него!': (None, 0.998),
#   'и което беше най-лошото, да бъде съучастник или най-малкото свидетел на бандитското спиране на един от товарните влакове по този участък.': (3.076,
#    3.825),
#   'още повече че карл не е роден в мадрид, нито изобщо в испания.': (None,
#    1.027),
#   'това обаче е много трудна задача за решаване и ще са нужни много години, преди да видим изграждането на полезни реактори за синтез.': (5.455,
#    6.011),
#   'според слухове граничните ни земи с баязид били размирни и той не смеел да изтегли оттам най-добрата си войска.': (None,
#    0.971),
#   'по такъв начин този проблем с военните превози е решен.': (None, 1.406),
#   'във всеки случай сега съм сам и изоставен.': (None, 0.964),
#   'и между другото въпросният „един час време отдавна беше минал.': (0.563,
#    1.386),
#   'всичко това спомогна най-вече и за този неочакван случай, благодарение на който сега се променя, може да се каже, цялата ни съдба.': (6.815,
#    7.869000000000001),
#   'в същност тя не „заставаше, а някак витаеше наоколо му като една сянка, която неочаквано беше добила едно ново измерение, плътността.': (None,
#    0.809),
#   'както е известно светът не е останал без добри хора.': (None, 1.04),
#   'сега той почна едно сепнато pizzicato, което по негово мнение изображаваше песента: „открадна-ла сей, бабината, сла-сланин-каа, сланинка, откраднала сей бабината сланинка“… която „сланинка “цяла е открадната от чешката „slaninka“.': (3.35,
#    4.303),
#   'с една дума, всички бяха затънали в работа до гуша…': (None, 0.765),
#   'дето се вика, останаха с пръст и устата!': (None, 1.063),
#   'момичето бързешком извади парите и ги хвърли в найлоновия плик, но съдейки по всичко, сумата бе смехотворна.': (4.357,
#    5.524),
#   'пишете, за бога, пишете, ще чакам!': (0.461, 0.95),
#   'но все пак… моля ви да си спомните накъде хукна другият престъпник.': (0.405,
#    1.0070000000000001),
#   'тази операция е скъпа още и заради бащините чувства.': (0.411, 1.055),
#   'за кавказ ли е? равнодушно попита колка.': (1.12, 1.459),
#   'ами той, ако искаш да знаеш, дори мислите ни чува! камо ли разговорите…': (3.1,
#    3.6020000000000003),
#    1.157),
#   'kdo tohle ví? řekl nakladatel. snad jen vítr.': (1.948, 2.5629999999999997),
#   'chlapec ukryl více než 600 poštovních dokumentů, z toho 429 novoročních přání,': (3.358,
#    3.799),
#   'co nejrychleji přijdeme.': (0.28, 0.8310000000000001),
#   'ještě před půl stoletím bylo na takové dobývání třeba věnovat mnoho času (i týdny, dokonce i měsíce!).': (5.613,
#    6.113),
#   'zaslechl vrzání pantů asi přes čtyři střechy nedlouho potom, co jeho přítel odešel.': (3.772,
#    4.761),
#   'čím více a rychleji se nato bude rozšiřovat, tím rychleji zmizí v archivu': (None,
#    0.551),
#   'tygr dokáže šplhat (i když ne dobře), plavat, skákat na velké vzdálenosti.': (1.371,
#    1.688),
#   'já, musím se přiznat, jsem ji nechala u chatfieldů také proto, že bych s ní zrovna teď nerada zůstala o samotě.': (4.083,
#    5.013),
#   'máš pravdu, je nešťastná, ale vždyť to je jen knížka.': (1.836, 2.438),
#   'jistě ne méně než pět set měsíčně, ne-li plných šest set.': (0.441, 1.231),
#   'a už vůbec není jisté, zdali případné změny režimů budou k lepšímu.': (0.161,
#    0.674),
#   'potrvá mnoho let, než dojde ke stavbě použitelných fúzních reaktorů.': (1.831,
#    2.409),
#   'povídalo se, že předseda byl bílý jako stěna, opile vrávoral a něco blekotal. ': (None,
#    0.914),
#   'tímto způsobem se tam pro rusy otevírá obrovský obchodní potenciál.': (None,
#    0.938),
#   'v každém případě odneste kotě i misku.': (None, 1.073),
#   'mezi jiným jsem pozoroval, že dr kramář bude mít potíže.': (None, 0.688),
#   'lze říci, že trasu letu lze měnit pouze z důvodu zajištění bezpečnosti a ochrany zdraví.': (None,
#    0.906),
#   'jediné, co udělám ― jediné, co si troufnu udělat ― bude v podstatě taková hloupost…': (3.237,
#    3.7960000000000003),
#   'jak je známo, bzučet mohou jedině včely.': (None, 0.925),
#   'podle něj je tohle jeden z hlavních důvodů.': (None, 0.694),
#   'krátce řečeno, jako jeho stájník. a také byste ošetřoval psy.': (None,
#    1.064),
#   'posud nepozbyla své krásy, ani zdraví i byla, jak se říká krev a mléko.': (3.043,
#    3.747),
#   'nejdříve většina médií tvrdila, že za vraždou podle všeho stojí mafie.': (2.902,
#    3.54),
#   'lyšíš? páni jdou. proboha, heleno!': (2.33, 2.981),
#   'ale asi spíš v tom lepším: na bezpráví a násilí jsem citlivější.': (0.4,
#    0.995),
#   'ovšem jednu z nejdivnějších – a navíc patřičně zpolitizovanou.': (1.558,
#    2.269),
#   'a cos ty myslil? prášek, či co?': (2.729, None),
#   'nejen že nemohl vstát, ale připadalo mu, že nesmí ani otevřít oči.': (None,
#    0.505),
#   'některé sceny přečetli jsme několikrát za sebou; celý román jsme přečetli skoro dvakrát po sobě a po druhé líbil se nám skoro ještě víc než po prvé.': (7.683,
#    8.251999999999999),
#   'nic takového zjevně není v plánu.': (None, 0.768),
#   'do prčic, jaká loterie?': (None, 0.746),
#   'není to nic jiného než klamavá reklama.': (0.505, 1.3010000000000002),
#   'stál kousek od mostu, co dělí tajland od kambodže.': (0.27, 0.924),
#   'přesně tak, to je výborná rada. ': (None, 0.739),
#   'jak by ne! a oni měli určitě víc možností se bránit!': (None, 0.625),
#   'mám všeho všudy šestatřicet krejcarů.': (0.22, 0.867),
#   'navzdory tomu o ně mají zákazníci nebývalý zájem.': (None, 1.23),
#   'vagony metroplus jsou vždy zařazeny na konec vlaku směrem ke kapskému městu.': (2.424,
#    2.9779999999999998),
#   'útulný apartmán v blízkosti mumlavských vodopádů.': (1.087, 1.67),
#   'já jsem byla opět v jiném stavu a skoro celé těhotenství až po porod nejmladší dcerky jsem prožila ve strachu.': (3.703,
#    4.0649999999999995),
#   'má právo zničit všechny překážky ve formě institucí a tradic, jež omezují lidskou svobodu výběru.': (1.862,
#    2.4240000000000004),
#   'to vše za účelem násilného uchopení moci.': (0.412, 0.952),
#   'najednou v jeho nebohé hlavě cvakla nějaká záklopka, načež se jal vyzývavě vtipkovat na účet tělesných a duševních vlastností dívky.': (5.437,
#    5.9270000000000005),
#   'podepsala se roku 1992, ale v platnost vešla v roce 2002.': (2.793,
#    3.3470000000000004),
#   'nejdřív ty nové drželi v karanténě v prvním patře, pak je přepravili do cel nedaleko mé místnosti.': (4.762,
#    5.444),
#   'na útraty vojenského eráru, to se rozumí.': (None, 0.682),
#   'po skončení práce četla, co za den napsali, á viděla, jak se chmuří, pozorně naslouchaje.': (None,
#    0.604),
#   'pokud by však nesouhlasili, musejí připustit, že o dětech rozhodují rodiče, ale nikoli podle své libosti, nýbrž jedině a výhradně s ohledem na jejich zájem.': (8.706,
#    9.488)},
#  'UK': {"не раз я бачив, як вони, поранені стрілою, знаходячись далеко від хірургів, перев'язували себе, заліпивши рану жменею землі, змішаною на долоні з порцією власної слини.": (None,
#    1.301),
#   'їх, хоч як тасуй, у цій засаленій колоді все одно жодної пристойної карти не витягнеш.': (3.489,
#    3.944),
#   'от тільки шо нікого не було, аж осьдечки й він, де не взявся.': (0.278,
#    0.762),
#   'коли ж навідався до делятина, його хтось побачив і тут же здав.': (3.898,
#    4.202),
#   'цивілізований світ до сих пір не знає не те що літератури української, а й взагалі такої країни, такого народу.': (1.422,
#    1.924),
#   "респондент у відповідь на це поцікавився, чи не з'являється іноді над його зеленими столами привид композитора вагнера.": (1.333,
#    1.789),
#   'автомат полетів далеко убік, «корінь» в паніці кинувся в хащі.': (1.552,
#    2.422),
#   'всі хочуть командувати, але ніхто не хоче звалити на себе відповідальність…': (3.367,
#    3.803),
#   'по сутi, партія більшовиків брала на озброєння есерівську аграрну програму.': (None,
#    1.0),
#   'у якихсь мемуарах раневської я прочитала, що вона ціле життя любила пушкіна.': (3.595,
#    4.489),
#   'у 16 столітті в результаті зіткнень іспанських завойовників з групами корінних народів був створений парагвай, який раніше називався гігантською провінцією індійців.': (1.52,
#    2.217),
#   "перед сном вона обов'язково читала йому вголос, потім вони розмовляли про все на світі, поки останні слова не поринали в сон.": (5.222,
#    6.384),
#   'хіба що «варену» (цей давній напій українців називали ще варенухою, варьохою).': (None,
#    0.715),
#   'у результаті два види риб вимерли, а два інших виявилися під загрозою зникнення, в тому числі - горбатий головень.': (5.508,
#    6.474),
#   'будьте певні, що як тільки ви дістанетесь марини, все буде достатньо очевидним. ви зустрінете інших човнових попутників і вони поділяться з вами своєю інформацією.': (1.663,
#    2.182),
#   'виросте й стане ледацюгою, сутяжником, а то й бандюгою.': (2.906,
#    3.3890000000000002),
#   'після того як опір групи бухаріна було зламано, перегляду цього рішення ніщо не перешкоджало.': (None,
#    1.082),
#   'хоча, чим більше часу проходить, тим очевидніше те, що багато хто добре розумів ще в наповнені космічною романтикою шістдесяті.': (0.858,
#    1.448),
#   'тигр, як всебічно розвинутий атлет, може дертися вгору (хоча і не дуже вміло).': (4.292,
#    5.383),
#   'дімка прокинувся від того, що хтось його шарпав і кричав.': (1.27, 1.994),
#   'але ж і справді як добре!, - сказав він зненацька, ніби осяяний новою ідеєю.': (None,
#    0.605),
#   'злочин визнається вчиненим на території україни, якщо його виконавець або хоча б один із співучасників діяв на території україни.': (4.672,
#    5.04),
#   'цікаво послухати, а тим більше дати і свою «безцінну» пораду сзр.': (1.632,
#    2.118),
#   'однак, цю проблему дуже важко вирішити, і пройде багато років, перш ніж ми станемо свідками будівництва придатних термоядерних реакторів.': (4.573,
#    5.373),
#   'а те, що клуб, за чутками, кришує губернатор, теж особливого резонансу не викликало — нічого іншого від губернатора, в принципі, й не чекали.': (1.135,
#    2.011),
#   'таким чином, не треба було виходити з палацика у ті святочні дні, коли муситься трапезувати під відкритим небом.': (None,
#    1.178),
#   'що ж, доживемо до понеділка, хоча і він не обіцяє нам спокою, в будь-якому випадку, в телевізійному просторі.': (5.189,
#    6.27),
#   'були сказані наче між іншим дві чи одна фраза.': (1.168,
#    1.7409999999999999),
#   'це, можна сказати, взірець ставлення до рідної мови.': (0.832,
#    1.6099999999999999),
#   'які ж вони всі, в істоті, були більшовики, які нелюди.': (1.319, 2.292),
#   'тургенєв, наприклад, в тих же 40-х роках дає свої «записки охотника», в яких, як відомо, ідеалізує селянина і підносить його крізь призму свого ліберально-поміщицького світогляду.': (5.431,
#    6.257),
#   'безкрилий реалізм крабба не міг, за його думкою, передати усю повноту, всю чарівність і всю велич сільського життя.': (2.656,
#    4.016),
#   'одним словом, творчий елемент, елемент саморозвитку, самобутності переважав.': (None,
#    1.679),
#   'вона (як і сама оксана) безперервно курсує поміж києвом та нью-йорком, тусується, що називається, з американською літературною та інтелектуальною богемою.': (6.105,
#    7.105),
#   'судячи з усього, мвс дійсно дуже заважає комусь, хто прагне електорального тріумфу.': (None,
#    1.413),
#   '— ваша королівська величносте! мовчіть! мовчіть, ради бога! — заблагав янкель.': (3.092,
#    3.745),
#   'і все ж безуспішність спроб реалізувати в масовому масштабі заходи щодо організаційно-господарського зміщення колгоспів, пояснювалася руйнівним впливом продрозкладки.': (0.825,
#    1.4849999999999999),
#   'засуджений винен ще і в іншому злочині, вчиненому ним до постановлення попереднього вироку.': (1.732,
#    2.144),
#   'дай мені хоч якусь премію, чи що?': (1.753, None),
#   'що то люди живуть, не те що ми – світа білого за роботою не бачимо…': (1.753,
#    2.413),
#   'до речі, чи не вперше за історію українського слова друкованим способом відтворюється великоруська експресивна лексика.': (1.174,
#    1.716),
#   'reynevan tymczasem uciekał, a szło mu to tak, jak gdyby całe życie nie robił nic innego, tylko galopował w więzach.': (3.634,
#    4.439),
#   'kości zostają rzucone, w rezultacie czego wydarza się to, co jakoby - nieuniknione i nieuchronne.': (1.469,
#    2.4370000000000003),
#   'rzecz w tym, że wszystko, absolutnie wszystko na świecie, ma trzy aury.': (3.449,
#    3.884),
#   'chyba że książę niedomaga.': (None, 0.511),
#   'turystyka przyrodnicza przyciąga osoby lubiące spędzać czas na łonie natury, podziwiać krajobrazy, w tym dziką roślinność i zwierzęta.': (5.743,
#    6.172000000000001),
#   'jak tylko dolatywał mnie zapach spalonego węgla, od razu stawał mi przed oczyma początek mojej służby.': (None,
#    0.797),
#   'trądem nas zarazić gotów! albo i czym gorszym!': (1.574, 2.146),
#   'mniej więcej godzinę od momentu, kiedy zamilkły ostatnie strzały, wolf powiedział, że pojedzie na zwiad i pojechał sam.': (1.203,
#    2.149),
#   'a im większy sekret, tym większa nagroda.': (0.518, 1.036),
#   'mówię ci to, byś znał moje zamiary, choć i tak z pewnością domyśliłeś się ich po pytaniach, które stawiałem schillingowi.': (2.544,
#    3.174),
#   'pomiędzy nią a resztą pracowników nastąpiła krótka przerwa w czasie, wynikła z tego, że wszyscy najpierw podążyli w kierunku źródła hałasu.': (4.661,
#    5.629),
#   'ale przecież on tu diabli wiedzą jak narozrabia!': (None, 0.78),
#   'i gdyby chociaż los zesłał mu skruchę, gorącą skruchę, która łamie serce, spędza sen z powiek, taką skruchę, której straszliwe męczarnie nasuwają myśl o pętli i topieli!': (None,
#    0.938),
#   'ani tym bardziej na trzymających stronę albrechta katolików.': (1.158,
#    1.773),
#   'zanim się połapią, że to była rozgrywka.': (None, 0.485),
#   'do sierotek, które, jak głosi fama, ostro maszerują na północ i lada moment tu będą.': (1.201,
#    2.1260000000000003),
#   'w taki oto sposób wiem, kto położył kres romansowi wirydy hornig.': (None,
#    1.103),
#   'w każdym razie na węgry wywieźć cię nie zdołam.': (None, 0.653),
#   'nawiasem mówiąc, musiałem z tym doktorem uważać.': (None, 1.091),
#   'umiem załatwiać takie rzeczy. mam to, można powiedzieć, we krwi. od pokoleń.': (2.481,
#    3.0519999999999996),
#   'regułą, a w gruncie rzeczy zasługą przeoryszy było to, że każdy z gości występował z kazaniem lub wykładem dla mniszek.': (0.969,
#    1.705),
#   'okazało się, że tempe, jak wiadomo, był u szczytu, pani osłabędzka umarła na serce w nędzy.': (1.739,
#    2.981),
#   'podejrzanych nadal było ośniu ludzi, z czego dwoje, moim zdaniem, można wykluczyć z powodów psychologicznych.': (3.395,
#    4.0440000000000005),
#   'zrobił to jednym gestem i jednym słowem, reynevan w życiu nie widział równie sprawnie rzuconego zaklęcia.': (1.698,
#    2.597),
#   'ot, co znaczy wiedzieć, na jakiego konia postawić!': (0.983, 1.697),
#   'wygląda na to, że lubimy takie pochwały.': (None, 1.149),
#   'a, na miłosierdzie boskie! - zawołał - czy to ziemia jest rajem, żeby od niej wszystkiego dobrego razem wymagać było można!': (0.467,
#    1.9260000000000002),
#   'odróżnia nas... tak..., więc jednak': (2.665, None),
#   "odkrycie harvey'a ma obok praktycznego także i filozoficzne znaczenie.": (2.591,
#    3.08),
#   'pozwoliłem. bo co on, zniewolony czy jak? pogadaliśmy.': (2.591, 3.302),
#   'sami własny klasztor niszczą, w dodatku z ochotą.': (1.872, 2.418),
#   'to było nieomalże ostatnie nasze zwycięstwo.': (0.416, 0.9359999999999999),
#   'jej nic podobnego przydarzyć się nie mogło więc to miłosierdzie nie budziło w niej żadnych osobistych uczuć czy też obaw.': (0.559,
#    1.339),
#   'gdybyś nie palił… co tam, i tak wystarczy tylko na kartofle i chleb.': (1.624,
#    2.222),
#   'za to zająć się czasami którąś z dziewcząt ze służby, lecz nie inaczej jak w poufnym porozumieniu z marfą pietrowna.': (4.814,
#    5.447),
#   'ale baśka moja nieledwie w waćpanny leciech dlatego poczuwam się w tym aby zaś miała czasem jakowąś uciechę grzeczną, a młodemu wiekowi przystojną.': (1.52,
#    2.438),
#   'jeden z praskich mentorów reynevana usiłował dowodzić odnośnie lotów czarodziejskich, a to mianowicie, że są one poddane kontroli mentalnej wysmarowanej maścią lotną czarownicy lub czarownika.': (6.398,
#    7.411),
#   'a zasię! to była, podobna, pierwsza kokota w warszawie!': (None, 1.552),
#   'ha! orłowe gniazdo, ale nie wiadomo, czy się orzeł w nim znajdzie, jako był wiśniowiecki, czy jeno wrona?.': (7.379,
#    7.853999999999999),
#   'jeden z krzyżaków, nie bacząc na rozkaz brania żywcem, zamierzył się do pchnięcia w gardło.': (1.937,
#    2.827),
#   'tę świątynię na szczycie wzgórza wzniesiono w końcu ix wieku, za czasów panowania króla yasovarmana.': (2.669,
#    3.138),
#   'wiosna idzie, pomyślał sobie reynevan, idąc u boku szarleja rozmokłą miedzą.': (3.658,
#    4.026),
#   'nieboskłon ściemniał aż do głębokiego mroku zimnego kosmosu, weszli na orbitę ziemi.': (1.376,
#    1.7899999999999998),
#   'ponieważ strome stoki są w stanie utrzymać jedynie ograniczoną ilość śniegu, jego nadmiar będzie staczał się w postaci lawiny.': (6.068,
#    6.680999999999999),
#   'od strony bramy wrocławskiej słychać było strzały.': (None, 0.779),
#   'na prostokątnej generalskiej twarzy lemchena pojawiły się zmarszczki oznaczające ni to życzliwy uśmiech, ni to strapienie z powodu odrażającej aury, lub też, być może, z trudem opanowywaną chęć kichnięcia.': (8.141,
#    8.705),
#   'na mocy rozejmu i układu, wymuszonego na księciu oławskim ludwiku, udostępniono im szpital świętego świerada.': (None,
#    1.293),
#   'tak więc przerwy robili na świeżym powietrzu. niedaleko za siewierzem, pośród przydrożnej brzeziny.': (3.183,
#    4.178),
#   'w całym kraju korzysta z porady lekarskiej na koszt właścicieli 41% a wcale jej nie doznaje 59.': (2.918,
#    3.4650000000000003),
#   'zadowolę się jałmużną, datkiem jakim skromnym, a i to nie z góry bynajmniej, lecz po skończonym dziele.': (6.168,
#    7.246),
#   'klasyfikacji skazanych dokonuje się mając na uwadze następujące cechy.': (2.785,
#    3.3160000000000003)}}

# %%
def get_audio_duration_internal(file_path):
    audio = AudioSegment.from_file(file_path)
    duration_in_seconds = len(audio) / 1000  # Convert milliseconds to seconds
    return duration_in_seconds

def get_audio_duration(basedir, countryCode, index):
    mp3_file_1 = f"{basedir}{countryCode}_{index}_0" + EXTENSION
    mp3_file_2 = f"{basedir}{countryCode}_{index}_1" + EXTENSION
    #check if 3rd file exists
    mp3_file_3 = f"{basedir}{countryCode}_{index}_2" + EXTENSION
    # if 3rd file doesnt exist then just return the two paths
    if not os.path.exists(mp3_file_3):
        duration_1 = get_audio_duration_internal(mp3_file_1)
        duration_2 = get_audio_duration_internal(mp3_file_2)
        # return mp3_file_1, mp3_file_2, duration_1, duration_2
        return duration_1, duration_2
    else:
        duration_1 = get_audio_duration_internal(mp3_file_1)
        duration_2 = get_audio_duration_internal(mp3_file_2)
        duration_3 = get_audio_duration_internal(mp3_file_3)
        # return mp3_file_1, mp3_file_2, mp3_file_3, duration_1, duration_2, duration_3
        return duration_1, duration_2, duration_3

def combine_audio_files(input_file_paths, output_file_path):
    # Initialize an empty audio segment for the final combined audio
    combined_audio = AudioSegment.empty()


    # Iterate through the input file paths and concatenate them
    for file_path in input_file_paths:
        audio_segment = AudioSegment.from_file(file_path)
        combined_audio += audio_segment 
base_dir = 'data/audio_data/full_audio'

# %%
def get_conditional_surprisal(audio_data, audio_context, language):
    surprisal_values = {}

    for file_number, (phrase_ru, phrase_l2, sentence, audio_clip, duration) in audio_data.items():
        # Extract the specified audio segment
        start_time, end_time = audio_context[language][sentence]
        segment_start = int(round(start_time * 16000)) if start_time is not None else 0
        segment_end = int(round(end_time * 16000)) if end_time is not None else len(audio_clip)
        
        # Ensure segment indices are within the bounds of the audio_clip
        segment_start = max(0, min(segment_start, len(audio_clip)))
        segment_end = max(0, min(segment_end, len(audio_clip)))
        
        # Cut the audio segment from the original clip
        # Preprocess the audio data
        context_input_values = processor(audio_clip, return_tensors="pt", sampling_rate=16000).input_features
        
        # Create dummy decoder_input_ids
        decoder_input_ids = torch.tensor([[1, 1]]) * model.config.decoder_start_token_id
        
        # Generate logits from the model
        with torch.no_grad():
            context_logits = model(context_input_values, decoder_input_ids=decoder_input_ids).logits
                
        # Apply softmax to get probabilities
        context_probs = F.softmax(context_logits, dim=-1)
        # Extract the segment from the processed context
       #context_input_for_segment = context_input_values[:, segment_start:segment_end]
        #print('this is context_logits', context_input_values.size(), context_logits.size())
        # Extract the processed segment from the processed context
        surprisal_value = -torch.log(context_probs).mean().item()
        surprisal_values[file_number] = (phrase_ru, phrase_l2, sentence, surprisal_value)
        print(surprisal_value)
    return surprisal_values


# Save surprisal values for each language
for language in languages:
    print(language)
    audio_data_language = audio_data[language]
    # Create a new dictionary with only the first two entries for each language
    #audio_data_language = {key: audio_data[language][key] for key in ['1', '2']}
    surprisal_values_language = get_conditional_surprisal(audio_data_language, audio_duration, language)

    # Create directory if it doesn't exist
    save_directory = f"results/surprisal_whisper_medium_ru"
    os.makedirs(save_directory, exist_ok=True)
    # Create a list of dictionaries for DataFrame creation
    data_list = []
    
    for audio_number, surprisal_values in surprisal_values_language.items():
            expression_ru, expression_l2, sentence, surprisal_data = surprisal_values[0], surprisal_values[1], surprisal_values[2], surprisal_values[3]
            data_list.append({
                'audio_number': audio_number,
